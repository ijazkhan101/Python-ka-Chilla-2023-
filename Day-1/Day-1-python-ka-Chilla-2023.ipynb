# %% [markdown]
# ### Python ka Chilla 2023 | 01/01/2023 | Day-1

# %% [markdown]
# ### 1st Assignment

# %%
from IPython.display import Image
Image(filename='bodmas-rule.png')

# %% [markdown]
# ### Top IDE for python
# Here are some popular Integrated Development Environments (IDEs) for Python:
#
#     PyCharm
#     IDLE
#     Eclipse with PyDev
#     Wing
#     Spyder
#     Visual Studio Code
#     PyDev
#     Eric Python IDE
#     Rodeo
#     Pydev with Eclipse
#
# It's worth noting that the best IDE for you will depend on your specific needs and preferences. Some IDEs are more feature-rich and support a wider range of development tasks, while others are more lightweight and focused on providing an efficient code-editing environment.
